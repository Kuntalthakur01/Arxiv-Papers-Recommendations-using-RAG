# %%
pip install llama_index
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: C:\Users\amogh\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install llama-index-embeddings-huggingface
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: C:\Users\amogh\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install llama-index-embeddings-instructor
# Out:
# ...
#    ---------------------------------------- 0.0/171.5 kB ? eta -:--:--
#    -------------------------------------- - 163.8/171.5 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 171.5/171.5 kB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.3.1
#     Uninstalling sentence-transformers-3.3.1:
#       Successfully uninstalled sentence-transformers-3.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.3.1
# [notice] To update, run: C:\Users\amogh\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from llama_index.core.node_parser import JSONNodeParser
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.schema import ImageNode
from llama_index.core.readers.json import JSONReader
from llama_index.readers.file.docs.base import PDFReader
from llama_index.core.node_parser import HierarchicalNodeParser
from llama_index.core import Document
from pathlib import Path
from glob import glob
import os
import json
import base64

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core.node_parser import SemanticSplitterNodeParser
# from llama_index.embeddings.openai import OpenAIEmbedding
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# %%
directory_path = "D:/Amogh/Docs/ASU/Assignments/DPS/Project-2/json_files-4/"

files = os.listdir(directory_path)

    
# parser = JSONNodeParser()

# pipeline = IngestionPipeline(
#     transformations=[
#         SentenceSplitter(chunk_size=1024, chunk_overlap=20),
#         # TitleExtractor(),
#         # OpenAIEmbedding(),
#     ]
# )

splitter = SemanticSplitterNodeParser(
    buffer_size=1, breakpoint_percentile_threshold=85, embed_model=embed_model
)

for file in files[1:]:
    with open(directory_path+file, encoding='utf-8') as f:
        json_file = json.load(f)
        json_file = json.dumps(json_file)
        document = Document(text=json_file)
        # nodes = splitter.run(documents=[document])
        nodes = splitter.get_nodes_from_documents([document])
        break

# %%
for node in nodes[:10]:
    res = node.text
    print(res + "\n")
# Out:
# {"Title and Authors": "arXiv:0710.3901v4  [cs.DM]  11 Jul 2024\nA recursive linear time modular decomposition\nalgorithm via LexBFS\u2217\nDerek G. Corneil\u2020\nMichel Habib\u2021\nChristophe Paul\u00a7\nMarc Tedder\u00b6\nJuly 15, 2024", "Abstract": "Abstract\nA module of a graph G is a set M of vertices that have the same set of neighbours\noutside of M. Modules of a graphs form a so-called partitive family and thereby can be\nrepresented by a unique tree MD(G), called the modular decomposition tree. Motivated by\nthe central role of modules in numerous algorithmic graph theory questions, the problem\nof e\ufb03ciently computing MD(G) has been investigated since the early 70\u2019s.\nTo date the\nbest algorithms run in linear time but are all rather complicated. By combining previous\nalgorithmic paradigms developed for the problem, we are able to present a simpler linear-\ntime algorithm that relies on very simple data-structures, namely slice decomposition and\nsequences of roo
# ...

# %%
reader = PDFReader()
pdf_path = Path("D:/Amogh/Docs/ASU/Assignments/DPS/Project-2/2411.18657v1.pdf")
documents = reader.load_data(pdf_path)

# %%
from llama_index.core import Document
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.extractors import TitleExtractor
from llama_index.core.ingestion import IngestionPipeline, IngestionCache

# create the pipeline with transformations
pipeline = IngestionPipeline(
    transformations=[
        SentenceSplitter(chunk_size=1024, chunk_overlap=0),
        # TitleExtractor(),
        # OpenAIEmbedding(),
    ]
)

# run the pipeline
nodes = pipeline.run(documents=[document])
