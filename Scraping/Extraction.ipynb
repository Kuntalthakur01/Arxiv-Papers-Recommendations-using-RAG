# %% [markdown]
# TEXT AND TABLE EXTRACTION INTO JSON FILE FROM PDF

# %%
import fitz  # PyMuPDF
import os
import json
import re

# Your provided sections dictionary
sections = {
    "title": r"\btitle\b",
    "abstract": r"\babstract\b",
    "keywords": r"\bkeywords\b|\bkey\s*words\b",
    "introduction": r"\bintroduction\b|\bbackground\b",
    "literature_review": r"\bliterature\s+review\b|\brelated\s+work\b|\bprior\s+work\b|\bstate\s+of\s+the\s+art\b",
    "theoretical_framework": r"\btheoretical\s+framework\b",
    "methodology": r"\bmethodology\b|\bmethods\b|\bmaterials\s+and\s+methods\b|\bexperimental\s+procedures\b|\bmethod\b",
    "data_collection": r"\bdata\s+collection\b",
    "data_analysis": r"\bdata\s+analysis\b",
    "experiments": r"\bexperiments?\b|\bexperimental\s+(setup|design|results)\b",
    "results": r"\bresults?\b|\bfindings\b",
    "discussion": r"\bdiscussion\b|\banalysis\b|\binterpretation\b|\bresults\s+and\s+discussion\b",
    "conclusion": r"\bconclusion\b|\bsummary\b|\bconcluding\s+remarks\b",
    "future_work": r"\bfuture\s+work\b|\bfuture\s+directions\b|\bfurther\s+research\b",
    "acknowledgements": r"\backnowledgements?\b|\bthanks\b",
    "references": r"\breferences\b|\bbibliography\b|\bworks\s+cited\b",
    "appendix": r"\bappendix\b|\bappendices\b",
    "supplementary_material": r"\bsupplementary\s+(material|information)\b",
    "author_information": r"\bauthor\s+(information|details|biography|bios)\b",
    "conflict_of_interest": r"\bconflicts?\s+of\s+interest\b|\bcompeting\s+interests?\b",
    "funding": r"\bfunding\b|\bfunding\s+sources\b",
    "ethics_statement": r"\bethics\s+statement\b|\bethical\s+approval\b",
    "abbreviations": r"\babbreviations\b|\blist\s+of\s+abbreviations\b",
    "glossary": r"\bglossary\b",
    "implementation": r"\bimplementation\b",
    "evaluation": r"\bevaluation\b",
    "validation": r"\bvalidation\b",
    "limitations": r"\blimitations\b|\bscope\s+and\s+limitations\b",
    "related_work": r"\brelated\s+work\b|\brelated\s+studies\b",
    "study_design": r"\bstudy\s+design\b|\bresearch\s+design\b",
    "objectives": r"\bobjectives?\b|\bgoals?\b|\baims?\b",
    "hypotheses": r"\bhypotheses?\b",
    "problem_statement": r"\bproblem\s+statement\b|\bresearch\s+problem\b",
    "data_and_methods": r"\bdata\s+and\s+methods\b",
    "experimental_setup": r"\bexperimental\s+setup\b|\bexperiment\s+setup\b",
    "findings": r"\bfindings\b",
    "analysis": r"\banalysis\b",
    "author_contributions": r"\bauthor\s+contributions?\b",
    "data_availability": r"\bdata\s+availability\b|\bavailability\s+of\s+data\b",
    "supplementary_information": r"\bsupplementary\s+information\b",
    "notes": r"\bnotes\b",
    "footnotes": r"\bfootnotes\b",
    "preface": r"\bpreface\b",
    "foreword": r"\bforeword\b",
    "prologue": r"\bprologue\b",
    "epilogue": r"\bepilogue\b",
    "afterword": r"\bafterword\b",
    "about_the_author": r"\babout\s+the\s+author\b|\bauthor\s+bio\b",
    "index": r"\bindex\b",
    "list_of_figures": r"\blist\s+of\s+figures\b",
    "list_of_tables": r"\blist\s+of\s+tables\b",
    "executive_summary": r"\bexecutive\s+summary\b",
    "acknowledgments": r"\backnowledgments\b",
    "copyright": r"\bcopyright\b",
    "patents": r"\bpatents\b",
    "sponsors": r"\bsponsors?\b",
    "disclaimer": r"\bdisclaimer\b",
    "dedication": r"\bdedication\b",
    "transparency_statement": r"\btransparency\s+statement\b",
    "statistical_analysis": r"\bstatistical\s+analysis\b",
    "methodological_approach": r"\bmethodological\s+approach\b",
    "experimental_methods": r"\bexperimental\s+methods\b",
    "design_and_methods": r"\bdesign\s+and\s+methods\b",
    "case_study": r"\bcase\s+study\b|\bcase\s+studies\b",
    "materials": r"\bmaterials\b",
    "supplementary_results": r"\bsupplementary\s+results\b",
    "recommendations": r"\brecommendations\b",
    "policy_implications": r"\bpolicy\s+implications\b",
    "theoretical_implications": r"\btheoretical\s+implications\b",
    "practical_implications": r"\bpractical\s+implications\b",
    "abstract_figure": r"\babstract\s+figure\b",
    "graphical_abstract": r"\bgraphical\s+abstract\b",
    "main_text": r"\bmain\s+text\b",
    "body": r"\bbody\b",
    "review_of_literature": r"\breview\s+of\s+literature\b",
}

def extract_pdf_to_json_with_sections(pdf_path, output_path):
    try:
        doc = fitz.open(pdf_path)
        data = {}
        content = ""

        # Combine text from all pages
        for page_num in range(len(doc)):
            page = doc[page_num]
            content += page.get_text("text") + "\n"

        # Convert 'sections' patterns into compiled regular expressions
        predefined_sections = {}
        for section_name, pattern in sections.items():
            # Adjust the section name to be more readable
            readable_section_name = ' '.join(word.capitalize() for word in section_name.split('_'))
            # Adjust the pattern to match section headings at the start of a line
            adjusted_pattern = re.compile(rf"(?im)^\s*({pattern})\s*$")
            predefined_sections[readable_section_name] = adjusted_pattern

        # Find all section headers and their positions
        section_positions = []
        for section_name, pattern in predefined_sections.items():
            for match in pattern.finditer(content):
                position = match.start()
                section_positions.append((position, section_name))

        # Remove duplicates and sort sections based on their positions in the text
        section_positions = list(set(section_positions))
        section_positions.sort()

        # Extract content before the first section as 'Title and Authors'
        if section_positions:
            first_section_start = section_positions[0][0]
            title_and_authors = content[:first_section_start].strip()
            if title_and_authors:
                data['Title and Authors'] = title_and_authors
        else:
            # If no sections are found, consider the entire content as 'Title and Authors'
            data['Title and Authors'] = content.strip()

        # Extract text between sections
        for i, (start_pos, section_name) in enumerate(section_positions):
            if i + 1 < len(section_positions):
                end_pos = section_positions[i + 1][0]
            else:
                end_pos = len(content)
            section_text = content[start_pos:end_pos].strip()
            data[section_name] = section_text

        # Extract tables and their descriptions
        table_pattern = re.compile(r'(?i)(Table\s*\d+[\.\:]*\s*)(.*?)\n', re.DOTALL)
        tables = []
        for match in table_pattern.finditer(content):
            table_title = match.group(1).strip()
            table_description = match.group(2).strip()
            tables.append({
                'Table Title': table_title,
                'Table Description': table_description
            })
        if tables:
            data['Tables'] = tables

        # DEBUG: Print extracted sections
        print(f"Extracted sections for {pdf_path}: {list(data.keys())}\n")

        # Save to JSON if data is not empty
        if data:
            with open(output_path, "w", encoding="utf-8") as json_file:
                json.dump(data, json_file, indent=4, ensure_ascii=False)
            print(f"JSON saved to {output_path}")
        else:
            print(f"No sections found for {pdf_path}. Skipping...")

    except Exception as e:
        print(f"Failed to process {pdf_path}: {e}")

if __name__ == "__main__":
    pdf_directory = "/Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024"
    output_directory = "/Users/kuntal/Documents/Github/arxiv scraper/json_files-4"
    os.makedirs(output_directory, exist_ok=True)

    for pdf_file in os.listdir(pdf_directory):
        if pdf_file.endswith(".pdf"):
            pdf_path = os.path.join(pdf_directory, pdf_file)
            output_path = os.path.join(output_directory, f"{os.path.splitext(pdf_file)[0]}.json")
            extract_pdf_to_json_with_sections(pdf_path, output_path)
# Out:
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.05385.pdf: ['Title and Authors', 'Abstract', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1807.05385.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2004.06795.pdf: ['Title and Authors', 'Abstract', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2004.06795.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.09342.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.09342.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.08413.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.08413.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.00140.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Conclusion', 'References', 'Acknowledgments', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1810.00140.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2001.03741.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Conclusion', 'Funding', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2001.03741.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2009.07463.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2009.07463.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.03556.pdf: ['Title and Authors', 'Index', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1812.03556.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1903.00374.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Experiments', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1903.00374.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2005.07946.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Methodology', 'Discussion', 'Conclusion', 'References', 'Supplementary Material']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2005.07946.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.08532.pdf: ['Title and Authors', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.08532.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.04096.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.04096.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1907.02916.pdf: ['Title and Authors', 'Abstract', 'Objectives', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1907.02916.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.01266.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.01266.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.00197.pdf: ['Title and Authors', 'Conclusion', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1810.00197.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2009.10862.pdf: ['Title and Authors', 'Conclusion', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2009.10862.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.10394.pdf: ['Title and Authors', 'Introduction', 'Appendix', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.10394.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2009.01947.pdf: ['Title and Authors', 'Abstract', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2009.01947.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.08880.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.08880.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1907.05062.pdf: ['Title and Authors', 'Introduction', 'Methodology', 'Experiments', 'Discussion', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1907.05062.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.00004.pdf: ['Title and Authors', 'Introduction', 'Funding', 'Acknowledgments']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1609.00004.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.06638.pdf: ['Title and Authors', 'Abstract', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1812.06638.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.05995.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgements', 'References', 'Appendix', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1802.05995.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1510.01008.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1510.01008.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1904.00847.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1904.00847.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.01855.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Methodology', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1804.01855.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.10330.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Conclusion', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1805.10330.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.07287.pdf: ['Title and Authors', 'Abstract', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.07287.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2005.08644.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2005.08644.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2002.06816.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Validation', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2002.06816.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2003.06281.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Methodology', 'Experiments', 'Discussion', 'References', 'Appendix', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2003.06281.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.02538.pdf: ['Title and Authors', 'Abstract', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.02538.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2005.01648.pdf: ['Title and Authors', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2005.01648.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.00743.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.00743.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.00757.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.00757.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.07840.pdf: ['Title and Authors', 'Abstract', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1808.07840.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.05267.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Methodology', 'Results', 'Discussion', 'Conclusion', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1710.05267.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.06991.pdf: ['Title and Authors', 'Abstract', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1701.06991.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.00810.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Analysis', 'Discussion', 'Problem Statement', 'Results', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.00810.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1910.07655.pdf: ['Title and Authors', 'Methodology', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1910.07655.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1909.04559.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Body', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1909.04559.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2009.04552.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Experiments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2009.04552.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2008.12019.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Appendix', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2008.12019.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2008.09439.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Conclusion', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2008.09439.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2005.08917.pdf: ['Title and Authors', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2005.08917.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.07621.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Conclusion', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.07621.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.00583.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.00583.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1612.07844.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1612.07844.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.03458.pdf: ['Title and Authors', 'Implementation', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.03458.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2012.14926.pdf: ['Title and Authors', 'Methodology', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2012.14926.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1904.07735.pdf: ['Title and Authors', 'Abstract', 'Keywords', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1904.07735.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.06842.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Conclusion', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1712.06842.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0710.3901.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References', 'Implementation']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/0710.3901.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2012.01668.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2012.01668.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.14721.pdf: ['Title and Authors', 'Methodology', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.14721.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1901.01767.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1901.01767.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0904.3742.pdf: ['Title and Authors', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/0904.3742.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2010.09471.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2010.09471.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2010.04633.pdf: ['Title and Authors', 'Abstract', 'Conclusion', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2010.04633.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1911.08303.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1911.08303.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.03275.pdf: ['Title and Authors', 'Objectives', 'References', 'Methodology']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.03275.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.10300.pdf: ['Title and Authors', 'Analysis', 'Discussion', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.10300.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.08723.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1708.08723.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.00117.pdf: ['Title and Authors', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1812.00117.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.05690.pdf: ['Title and Authors', 'Abstract', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.05690.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.13714.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Methodology', 'Results', 'Discussion', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.13714.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2009.08618.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2009.08618.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.08855.pdf: ['Title and Authors', 'Conclusion', 'References', 'Acknowledgements', 'Author Information']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.08855.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.01065.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.01065.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.05834.pdf: ['Title and Authors', 'Introduction', 'Methodology', 'Implementation', 'Experiments', 'Evaluation', 'Results', 'Discussion', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1703.05834.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.08405.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Conclusion', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.08405.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.06787.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1811.06787.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04310.pdf: ['Title and Authors', 'References', 'Case Study']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.04310.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1907.08355.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1907.08355.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2003.12801.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2003.12801.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.10604.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.10604.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.00371.pdf: ['Title and Authors', 'Abstract', 'Index', 'Discussion', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.00371.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1905.07145.pdf: ['Title and Authors', 'References', 'Appendix']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1905.07145.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2009.12872.pdf: ['Title and Authors', 'Abstract', 'Acknowledgements', 'Data Availability', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2009.12872.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1309.0193.pdf: ['Title and Authors']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1309.0193.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2008.08530.pdf: ['Title and Authors', 'Introduction', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2008.08530.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.00674.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.00674.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2010.11559.pdf: ['Title and Authors', 'Abstract', 'Keywords', 'Funding', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2010.11559.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2012.10016.pdf: ['Title and Authors', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2012.10016.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1908.10406.pdf: ['Title and Authors', 'Analysis', 'Discussion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1908.10406.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.04255.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.04255.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1912.12150.pdf: ['Title and Authors', 'Methodology', 'References', 'Appendix', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1912.12150.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.11896.pdf: ['Title and Authors', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.11896.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2008.10431.pdf: ['Title and Authors', 'Abstract', 'Keywords', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2008.10431.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09350.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.09350.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1005.2465.pdf: ['Title and Authors']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1005.2465.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.03747.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.03747.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1901.02938.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1901.02938.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.09957.pdf: ['Title and Authors', 'Abstract', 'Keywords', 'Introduction', 'Methodology', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1802.09957.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2012.01494.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2012.01494.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.04901.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1703.04901.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.08357.pdf: ['Title and Authors', 'Introduction', 'Discussion', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1606.08357.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2004.02653.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Methodology', 'Results', 'Conclusion', 'Acknowledgments', 'Appendix', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2004.02653.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.04094.pdf: ['Title and Authors', 'Methodology', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.04094.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.10785.pdf: ['Title and Authors', 'Validation', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.10785.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.01042.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.01042.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.12104.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Methodology', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.12104.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.04539.pdf: ['Title and Authors', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.04539.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.02790.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'References', 'Analysis', 'Discussion', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.02790.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.06448.pdf: ['Title and Authors', 'Abstract', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.06448.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2003.09038.pdf: ['Title and Authors', 'Appendix', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2003.09038.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2009.04553.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2009.04553.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.14371.pdf: ['Title and Authors', 'Abstract', 'Results', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.14371.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.09320.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.09320.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.03712.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.03712.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0802.3414.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/0802.3414.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2002.04609.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Objectives', 'Conclusion', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2002.04609.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1901.09892.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Methodology', 'Experiments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1901.09892.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2010.09896.pdf: ['Title and Authors', 'Introduction', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2010.09896.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.17122.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.17122.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.08086.pdf: ['Title and Authors', 'Abstract', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1810.08086.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1908.01696.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Conclusion', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1908.01696.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.07886.pdf: ['Title and Authors', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1606.07886.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.03498.pdf: ['Title and Authors', 'Abstract', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1802.03498.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.03505.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Methodology', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.03505.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.08473.pdf: ['Title and Authors', 'Abstract', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.08473.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2010.00911.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Conclusion', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2010.00911.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2008.06680.pdf: ['Title and Authors', 'Results', 'References', 'Introduction', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2008.06680.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.17095.pdf: ['Title and Authors', 'Abstract', 'Acknowledgments', 'References', 'Appendix', 'Hypotheses', 'Objectives', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.17095.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.07144.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.07144.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.02641.pdf: ['Title and Authors', 'Abstract', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1811.02641.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.07622.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.07622.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.08638.pdf: ['Title and Authors', 'Results', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.08638.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1403.4434.pdf: ['Title and Authors', 'Abstract', 'Acknowledgments', 'References', 'Methodology', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1403.4434.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.10705.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.10705.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1908.06884.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1908.06884.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.10154.pdf: ['Title and Authors', 'Introduction', 'Results', 'Methodology', 'Acknowledgments']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.10154.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2002.01605.pdf: ['Title and Authors', 'Abstract', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2002.01605.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.12890.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.12890.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1912.09160.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1912.09160.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2002.03760.pdf: ['Title and Authors', 'Abstract', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2002.03760.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1901.11398.pdf: ['Title and Authors', 'Abstract', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1901.11398.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1505.00412.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Experiments', 'Results', 'Conclusion', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1505.00412.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.09235.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Problem Statement', 'Experiments', 'Analysis', 'Discussion', 'Conclusion', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.09235.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.01110.pdf: ['Title and Authors', 'Introduction', 'Experimental Setup', 'Results', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.01110.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.02713.pdf: ['Title and Authors', 'Methodology', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.02713.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.03061.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.03061.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.12042.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1805.12042.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.07000.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Acknowledgements', 'Experiments', 'Experimental Setup', 'Evaluation', 'Conclusion', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1804.07000.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.03903.pdf: ['Title and Authors', 'Abstract', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.03903.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2004.10860.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2004.10860.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.03380.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Implementation', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.03380.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.06702.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.06702.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.03234.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1701.03234.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.08691.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Experimental Setup', 'Experiments', 'Limitations', 'Literature Review', 'Related Work', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.08691.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.06853.pdf: ['Title and Authors', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.06853.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1911.06517.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1911.06517.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1908.04263.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1908.04263.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.00371.pdf: ['Title and Authors', 'Introduction', 'Acknowledgements']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.00371.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0903.2016.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/0903.2016.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.05001.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Objectives', 'Experiments', 'Methodology', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.05001.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1910.02302.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1910.02302.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.07170.pdf: ['Title and Authors', 'Acknowledgments', 'Funding', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.07170.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2008.07007.pdf: ['Title and Authors', 'Introduction', 'Acknowledgements', 'Conflict Of Interest', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2008.07007.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1911.07621.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1911.07621.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.11444.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Experimental Setup', 'Experiments', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.11444.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.11089.pdf: ['Title and Authors', 'Introduction', 'Evaluation', 'Data Collection', 'Results', 'Discussion', 'Limitations', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.11089.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13040.pdf: ['Title and Authors', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.13040.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.11456.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1807.11456.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2004.11201.pdf: ['Title and Authors', 'Abstract', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2004.11201.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1511.03086.pdf: ['Title and Authors', 'Abstract', 'Objectives', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1511.03086.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.05348.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.05348.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.00095.pdf: ['Title and Authors', 'Abstract', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1710.00095.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.02433.pdf: ['Title and Authors', 'Appendix', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.02433.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.10561.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.10561.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.14978.pdf: ['Title and Authors', 'Introduction', 'Index', 'Literature Review', 'Related Work', 'Methodology', 'Experimental Setup', 'Experiments', 'Evaluation', 'Conclusion', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.14978.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.00155.pdf: ['Title and Authors', 'Abstract', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1711.00155.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.04645.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Experimental Setup', 'Experiments', 'Evaluation', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.04645.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.17040.pdf: ['Title and Authors', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.17040.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1907.06781.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1907.06781.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.08069.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Evaluation', 'Discussion', 'Literature Review', 'Related Work', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.08069.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.05812.pdf: ['Title and Authors', 'Introduction', 'Methodology', 'Evaluation', 'Results', 'Discussion', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1807.05812.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.11042.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.11042.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2010.09710.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2010.09710.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2010.04220.pdf: ['Title and Authors', 'Abstract', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2010.04220.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.02465.pdf: ['Title and Authors', 'Methodology', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.02465.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2008.05412.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2008.05412.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07551.pdf: ['Title and Authors', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.07551.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2005.03074.pdf: ['Title and Authors', 'Introduction', 'Acknowledgements', 'Results', 'References', 'Analysis', 'Discussion', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2005.03074.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2008.07588.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Methodology', 'Results', 'References', 'Tables']
#
# ...
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.05943.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.12169.pdf: ['Title and Authors', 'Implementation', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.12169.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.01242.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.01242.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1911.00593.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1911.00593.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.00256.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.00256.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.10597.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.10597.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.01714.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.01714.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1411.3603.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1411.3603.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.01864.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1810.01864.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.10872.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.10872.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2004.10501.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2004.10501.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2005.13321.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2005.13321.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2010.11970.pdf: ['Title and Authors', 'Abstract', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2010.11970.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2012.00962.pdf: ['Title and Authors', 'References', 'Appendix']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2012.00962.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.02005.pdf: ['Title and Authors', 'Abstract', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.02005.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.06169.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Results', 'Appendix', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.06169.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1907.05325.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1907.05325.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1101.0350.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Results', 'Discussion', 'Acknowledgments', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1101.0350.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2101.00203.pdf: ['Title and Authors', 'Abstract', 'Experiments', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2101.00203.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1908.04127.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References', 'Objectives', 'Conclusion', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1908.04127.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1901.07643.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1901.07643.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1910.10330.pdf: ['Title and Authors', 'Introduction', 'Methodology', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1910.10330.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.08327.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Objectives', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.08327.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1909.04226.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1909.04226.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.04868.pdf: ['Title and Authors', 'Abstract', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1804.04868.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2004.11186.pdf: ['Title and Authors', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2004.11186.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.12639.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Implementation', 'Results', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.12639.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.06814.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.06814.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2009.03218.pdf: ['Title and Authors', 'Acknowledgments', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2009.03218.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2012.07823.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Experiments', 'Conclusion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2012.07823.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2007.14357.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2007.14357.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2002.07287.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2002.07287.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07563.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Future Work', 'Literature Review', 'Related Work', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.07563.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.10751.pdf: ['Title and Authors', 'Acknowledgements', 'References', 'Appendix', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.10751.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.09223.pdf: ['Title and Authors', 'Abstract', 'Appendix', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1804.09223.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.03494.pdf: ['Title and Authors', 'Introduction', 'Literature Review', 'Related Work', 'Methodology', 'Experiments', 'Conclusion', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1802.03494.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2003.06267.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2003.06267.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.02024.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Evaluation', 'Results', 'Discussion', 'Limitations', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.02024.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.09157.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1711.09157.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.08217.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1808.08217.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2003.05746.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2003.05746.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1403.6207.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1403.6207.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1909.10455.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Methodology', 'Discussion', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1909.10455.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1605.07896.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgements', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1605.07896.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.06775.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1805.06775.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.02429.pdf: ['Title and Authors', 'Methodology', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.02429.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.12974.pdf: ['Title and Authors', 'Introduction', 'Methodology', 'Acknowledgements', 'Appendix', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.12974.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.00032.pdf: ['Title and Authors', 'Abstract', 'References', 'Supplementary Material', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2104.00032.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2011.00836.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2011.00836.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.00718.pdf: ['Title and Authors', 'Methodology', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.00718.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1608.03417.pdf: ['Title and Authors', 'Abstract', 'Evaluation']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1608.03417.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2006.06863.pdf: ['Title and Authors', 'Abstract', 'Methodology', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2006.06863.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1906.03938.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1906.03938.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1702.00249.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Acknowledgments', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1702.00249.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1901.11343.pdf: ['Title and Authors', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1901.11343.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2103.05674.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2103.05674.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2002.02880.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2002.02880.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.00425.pdf: ['Title and Authors', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.00425.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.06430.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Literature Review', 'Related Work', 'Methodology', 'Experiments', 'Discussion', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1611.06430.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2102.09429.pdf: ['Title and Authors', 'References']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/2102.09429.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1706.00782.pdf: ['Title and Authors', 'Abstract', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1706.00782.json
# Extracted sections for /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1909.02253.pdf: ['Title and Authors', 'Abstract', 'Introduction', 'Experimental Setup', 'Experiments', 'Results', 'Literature Review', 'Related Work', 'Conclusion', 'Acknowledgements', 'References', 'Tables']
#
# JSON saved to /Users/kuntal/Documents/Github/arxiv scraper/json_files-4/1909.02253.json

# %% [markdown]
# IMAGE EXTRACTION

# %%
import fitz  # PyMuPDF
import os

# Define the input and output directories
pdf_dir = "/Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/"
output_base_dir = "/Users/kuntal/Documents/Github/arxiv scraper/images-3"

# Ensure the output base directory exists
os.makedirs(output_base_dir, exist_ok=True)

# Iterate over each file in the PDF directory
for pdf_file in os.listdir(pdf_dir):
    if pdf_file.endswith(".pdf"):
        # Construct the full path to the PDF file
        pdf_path = os.path.join(pdf_dir, pdf_file)
        
        # Extract the base name of the PDF file without the extension for folder naming
        folder_name = os.path.splitext(pdf_file)[0]
        
        # Create a full path for the new directory inside the output base directory
        output_folder_path = os.path.join(output_base_dir, folder_name)
        
        # Create a new directory with the folder name if it doesn't already exist
        os.makedirs(output_folder_path, exist_ok=True)
        
        # Open the PDF file using PyMuPDF
        pdf_document = fitz.open(pdf_path)
        
        for page_number in range(len(pdf_document)):
            page = pdf_document.load_page(page_number)
            image_list = page.get_images(full=True)
            
            # Initialize a flag to check if vector image is present
            vector_image_present = False
            
            if image_list:  # If raster images are found
                print(f"[+] Found {len(image_list)} raster image(s) on page {page_number+1} of {pdf_file}")
                for image_index, img in enumerate(image_list, start=1):
                    try:
                        xref = img[0]
                        base_image = pdf_document.extract_image(xref)
                        image_bytes = base_image["image"]
                        image_ext = base_image["ext"]
                        
                        # Save raster image
                        image_filename = os.path.join(output_folder_path, f"page_{page_number+1}_raster_image_{image_index}.{image_ext}")
                        with open(image_filename, "wb") as img_file:
                            img_file.write(image_bytes)
                        print(f"[+] Raster image saved as {image_filename}")
                    
                    except Exception as e:
                        print(f"[!] Could not process raster image {image_index} on page {page_number+1} of {pdf_file}: {e}")
            
            # Check if there are vector images
            try:
                # Attempt to identify vector images
                for img in page.get_images(full=True):
                    if img[7] == 0:  # Check if it's a vector image
                        vector_image_present = True
                        break
            except Exception as e:
                print(f"[!] Error checking for vector images: {e}")
            
            # Render and save full page ONLY if vector images are present
            if vector_image_present:
                try:
                    pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))  # Scale by 2x for better quality
                    rendered_image_path = os.path.join(output_folder_path, f"page_{page_number+1}_vector_rendered.png")
                    pix.save(rendered_image_path)
                    print(f"[+] Rendered vector graphics page saved as {rendered_image_path}")
                except Exception as e:
                    print(f"[!] Could not render page {page_number+1} of {pdf_file}: {e}")
        
        # Close the PDF document
        pdf_document.close()

# %% [markdown]
# METADATA CREATION:

# %%
import os
import json
import uuid

# Define your directories
base_dir = '/Users/kuntal/Documents/Github/arxiv scraper'
json_files_dir = os.path.join(base_dir, 'json_files')
equation_json_dir = os.path.join(base_dir, 'equation_json')
images_dir = os.path.join(base_dir, 'images')
output_dir = os.path.join(base_dir, 'metadata_output')

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to generate a unique ID
def generate_unique_id():
    return str(uuid.uuid4())

# Iterate over each paper's JSON file
for paper_json_file in os.listdir(json_files_dir):
    if paper_json_file.endswith('.json'):
        paper_id = os.path.splitext(paper_json_file)[0]
        paper_json_path = os.path.join(json_files_dir, paper_json_file)
        
        # Load paper metadata
        with open(paper_json_path, 'r') as f:
            paper_data = json.load(f)
        
        # Initialize the metadata dictionary
        metadata = {
            "paper_id": paper_data.get("paper_id", paper_id),
            "unique_id": generate_unique_id(),
            "text_file": f"{paper_id}.json",  # Direct path to the text file
            "images": [],
            "equations": [],  # Changed from 'formulas' to 'equations'
            "tables": []  # Direct table data is now here
        }
        
        # Process images
        paper_images_dir = os.path.join(images_dir, paper_id)
        if os.path.exists(paper_images_dir):
            for image_file in os.listdir(paper_images_dir):
                if image_file.lower().endswith(('.png', '.jpg', '.jpeg')):
                    image_id = os.path.splitext(image_file)[0]
                    image_data = {
                        "image_id": image_id,
                    }
                    metadata["images"].append(image_data)
        
        # Process equations
        equation_json_file = os.path.join(equation_json_dir, f'{paper_id}.json')
        if os.path.exists(equation_json_file):
            with open(equation_json_file, 'r') as eq_f:
                equations = json.load(eq_f)
                if isinstance(equations, dict):  # Ensure the JSON contains a dictionary
                    for eq_key, eq_latex in equations.items():
                        equation_id = generate_unique_id()
                        equation_data = {
                            "equation_id": equation_id,
                            "equation_key": eq_key,  # Include the key as metadata
                            "latex": eq_latex  # Store the actual LaTeX code
                        }
                        metadata["equations"].append(equation_data)
        
        # Process tables directly from JSON file
        if "Tables" in paper_data:
            for idx, table in enumerate(paper_data["Tables"], start=1):
                table_id = generate_unique_id()
                table_data = {
                    "table_id": table_id,
                    "title": table.get("Table Title", ""),
                    "description": table.get("Table Description", ""),
                }
                metadata["tables"].append(table_data)
        
        # Write the metadata to a JSON file
        output_file = os.path.join(output_dir, f'{paper_id}_metadata.json')
        with open(output_file, 'w') as out_f:
            json.dump(metadata, out_f, indent=4)

        print(f"Metadata for paper {paper_id} has been created.")

# %% [markdown]
# FINAL FOLDER CREATION WITH PROPER FORMAT :

# %%
import os
import json
import shutil

# Define your directories
base_dir = '/Users/kuntal/Documents/Github/arxiv scraper'
json_files_dir = os.path.join(base_dir, 'json_files')
images_dir = os.path.join(base_dir, 'images')
equation_json_dir = os.path.join(base_dir, 'equation_json')
metadata_output_dir = os.path.join(base_dir, 'metadata_output')
output_dir = os.path.join(base_dir, '2024_arxic_papers_CS')

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Iterate over each paper's JSON file
for paper_json_file in os.listdir(json_files_dir):
    if paper_json_file.endswith('.json'):
        paper_id = os.path.splitext(paper_json_file)[0]
        paper_json_path = os.path.join(json_files_dir, paper_json_file)
        
        # Create paper-specific folder structure
        paper_folder = os.path.join(output_dir, paper_id)
        os.makedirs(paper_folder, exist_ok=True)
        os.makedirs(os.path.join(paper_folder, 'images'), exist_ok=True)
        os.makedirs(os.path.join(paper_folder, 'equations'), exist_ok=True)
        
        # Copy metadata from metadata_output if available
        metadata_file_path = os.path.join(metadata_output_dir, f'{paper_id}_metadata.json')
        metadata_path = os.path.join(paper_folder, 'metadata.json')
        if os.path.exists(metadata_file_path):
            shutil.copy(metadata_file_path, metadata_path)
        else:
            shutil.copy(paper_json_path, metadata_path)
        
        # Create paper_name.json with only text and tables
        text_file_path = os.path.join(paper_folder, f'{paper_id}.json')
        with open(paper_json_path, 'r') as f:
            paper_data = json.load(f)
            text_content = {
                "title": paper_data.get("title", ""),
                "abstract": paper_data.get("abstract", ""),
                "introduction": paper_data.get("Introduction", ""),
                "tables": paper_data.get("Tables", [])
            }
            with open(text_file_path, 'w') as text_file:
                json.dump(text_content, text_file, indent=4)
        
        # Update metadata to include path to text file
        with open(metadata_path, 'r+') as metadata_file:
            metadata = json.load(metadata_file)
            metadata["text_file"] = os.path.join(paper_id, f'{paper_id}.json')
            metadata_file.seek(0)
            json.dump(metadata, metadata_file, indent=4)
            metadata_file.truncate()
        
        # Process images
        paper_images_dir = os.path.join(images_dir, paper_id)
        if os.path.exists(paper_images_dir):
            for image_file in os.listdir(paper_images_dir):
                if image_file.lower().endswith(('.png', '.jpg', '.jpeg')):
                    src_path = os.path.join(paper_images_dir, image_file)
                    dest_path = os.path.join(paper_folder, 'images', image_file)
                    shutil.copy(src_path, dest_path)
        
        # Process equations (formerly formulas)
        equation_json_path = os.path.join(equation_json_dir, f'{paper_id}.json')
        if os.path.exists(equation_json_path):
            with open(equation_json_path, 'r') as eq_f:
                equations = json.load(eq_f)
                for idx, equation in enumerate(equations, start=1):
                    equation_filename = f'page_{idx}_equation_{idx}.txt'
                    equation_path = os.path.join(paper_folder, 'equations', equation_filename)
                    with open(equation_path, 'w') as equation_file:
                        equation_file.write(equation)
        
        print(f"Organized data for paper {paper_id} into {paper_folder}")
