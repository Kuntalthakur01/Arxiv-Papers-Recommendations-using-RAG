# %%
pip install paperscraper
# Out:
# Collecting paperscraper
#   Downloading paperscraper-0.2.14-py3-none-any.whl.metadata (13 kB)
# Collecting arxiv>=1.4.2 (from paperscraper)
#   Downloading arxiv-2.1.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting pymed-paperscraper (from paperscraper)
#   Downloading pymed_paperscraper-0.0.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paperscraper) (2.2.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paperscraper) (2.32.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paperscraper) (4.66.5)
# Collecting scholarly>=1.0.0 (from paperscraper)
#   Downloading scholarly-1.7.11-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paperscraper) (0.12.2)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paperscraper) (3.6.3)
# Collecting matplotlib-venn (from paperscraper)
#   Downloading matplotlib-venn-1.1.1.tar.gz (40 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: bs4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from paperscraper) (0.0.2)
# Collecting impact-factor>=1.1.0 (from paperscraper)
#   Downloading impact_factor-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting thefuzz (from paperscraper)
#   Downloading thefuzz-0.22.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting pytest (from paperscraper)
#   Downloading pytest-8.3.3-py3-none-any.whl.metadata (7.5 kB)
# Collecting feedparser~=6.0.10 (from arxiv>=1.4.2->paperscraper)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from impact-factor>=1.1.0->paperscraper) (4.9.3)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from impact-factor>=1.1.0->paperscraper) (8.1.3)
# Collecting openpyxl (from impact-factor>=1.1.0->paperscraper)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pygments in /Users/kuntal/Library/Python/3.11/lib/python/site-packages (from impact-factor>=1.1.0->paperscraper) (2.14.0)
# Collecting webrequests (from impact-factor>=1.1.0->paperscraper)
#   Downloading webrequests-1.0.8-py3-none-any.whl.metadata (1.8 kB)
# Collecting sql-manager (from impact-factor>=1.1.0->paperscraper)
#   Downloading sql_manager-1.0.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->paperscraper) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->paperscraper) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->paperscraper) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->paperscraper) (2024.8.30)
# Requirement already satisfied: arrow in /Users/kuntal/Library/Python/3.11/lib/python/site-packages (from scholarly>=1.0.0->paperscraper) (1.2.3)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scholarly>=1.0.0->paperscraper) (4.12.3)
# Collecting bibtexparser (from scholarly>=1.0.0->paperscraper)
#   Downloading bibtexparser-1.4.2.tar.gz (55 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: deprecated in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scholarly>=1.0.0->paperscraper) (1.2.14)
# Requirement already satisfied: fake-useragent in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scholarly>=1.0.0->paperscraper) (1.5.1)
# Requirement already satisfied: free-proxy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scholarly>=1.0.0->paperscraper) (1.1.2)
# Requirement already satisfied: httpx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scholarly>=1.0.0->paperscraper) (0.27.0)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scholarly>=1.0.0->paperscraper) (1.0.1)
# Requirement already satisfied: selenium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scholarly>=1.0.0->paperscraper) (4.23.1)
# Collecting sphinx-rtd-theme (from scholarly>=1.0.0->paperscraper)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scholarly>=1.0.0->paperscraper) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (1.4.4)
# Requirement already satisfied: numpy>=1.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (10.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->paperscraper) (2.9.0.post0)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib-venn->paperscraper) (1.10.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->paperscraper) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->paperscraper) (2024.1)
# Collecting iniconfig (from pytest->paperscraper)
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2,>=1.5 (from pytest->paperscraper)
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from thefuzz->paperscraper)
#   Downloading rapidfuzz-3.10.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting sgmllib3k (from feedparser~=6.0.10->arxiv>=1.4.2->paperscraper)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->paperscraper) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from beautifulsoup4->scholarly>=1.0.0->paperscraper) (2.3.2.post1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from deprecated->scholarly>=1.0.0->paperscraper) (1.15.0)
# Requirement already satisfied: anyio in /Users/kuntal/Library/Python/3.11/lib/python/site-packages (from httpx->scholarly>=1.0.0->paperscraper) (3.6.2)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx->scholarly>=1.0.0->paperscraper) (1.0.5)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx->scholarly>=1.0.0->paperscraper) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpcore==1.*->httpx->scholarly>=1.0.0->paperscraper) (0.14.0)
# Collecting et-xmlfile (from openpyxl->impact-factor>=1.1.0->paperscraper)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests[socks]->scholarly>=1.0.0->paperscraper) (1.7.1)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium->scholarly>=1.0.0->paperscraper) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium->scholarly>=1.0.0->paperscraper) (0.9.2)
# Requirement already satisfied: websocket-client~=1.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium->scholarly>=1.0.0->paperscraper) (1.8.0)
# Collecting sphinx<9,>=6 (from sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading sphinx-8.1.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: docutils<0.22,>0.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sphinx-rtd-theme->scholarly>=1.0.0->paperscraper) (0.21.2)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sqlalchemy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sql-manager->impact-factor>=1.1.0->paperscraper) (2.0.34)
# Collecting prettytable (from sql-manager->impact-factor>=1.1.0->paperscraper)
#   Downloading prettytable-3.12.0-py3-none-any.whl.metadata (30 kB)
# Collecting simple-loggers (from sql-manager->impact-factor>=1.1.0->paperscraper)
#   Downloading simple_loggers-1.0.5-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: chardet in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from webrequests->impact-factor>=1.1.0->paperscraper) (3.0.4)
# Collecting sphinxcontrib-applehelp>=1.0.7 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp>=1.0.6 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.6 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath>=1.0.1 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-qthelp>=1.0.6 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: Jinja2>=3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper) (3.1.2)
# Collecting pygments (from impact-factor>=1.1.0->paperscraper)
#   Using cached pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting snowballstemmer>=2.2 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting babel>=2.13 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting alabaster>=0.7.14 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading alabaster-1.0.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting imagesize>=1.3 (from sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper)
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=19.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium->scholarly>=1.0.0->paperscraper) (22.2.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium->scholarly>=1.0.0->paperscraper) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium->scholarly>=1.0.0->paperscraper) (1.10)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium->scholarly>=1.0.0->paperscraper) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium->scholarly>=1.0.0->paperscraper) (1.2.0)
# Requirement already satisfied: wcwidth in /Users/kuntal/Library/Python/3.11/lib/python/site-packages (from prettytable->sql-manager->impact-factor>=1.1.0->paperscraper) (0.2.6)
# Requirement already satisfied: colorama in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from simple-loggers->sql-manager->impact-factor>=1.1.0->paperscraper) (0.4.6)
# Collecting coloredlogs (from simple-loggers->sql-manager->impact-factor>=1.1.0->paperscraper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from Jinja2>=3.1->sphinx<9,>=6->sphinx-rtd-theme->scholarly>=1.0.0->paperscraper) (2.1.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->simple-loggers->sql-manager->impact-factor>=1.1.0->paperscraper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Downloading paperscraper-0.2.14-py3-none-any.whl (42 kB)
# Downloading arxiv-2.1.3-py3-none-any.whl (11 kB)
# Downloading impact_factor-1.1.2-py3-none-any.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading scholarly-1.7.11-py3-none-any.whl (39 kB)
# Downloading pymed_paperscraper-0.0.1-py3-none-any.whl (10 kB)
# Downloading pytest-8.3.3-py3-none-any.whl (342 kB)
# Downloading thefuzz-0.22.1-py3-none-any.whl (8.2 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading rapidfuzz-3.10.1-cp311-cp311-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.7 MB/s eta 0:00:00a 0:00:01
# Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 4.8 MB/s eta 0:00:00a 0:00:01
# Downloading sql_manager-1.0.5-py3-none-any.whl (5.5 kB)
# Downloading webrequests-1.0.8-py3-none-any.whl (4.7 kB)
# Downloading sphinx-8.1.3-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 4.5 MB/s eta 0:00:00a 0:00:01
# Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading prettytable-3.12.0-py3-none-any.whl (31 kB)
# Downloading simple_loggers-1.0.5-py3-none-any.whl (3.0 kB)
# Downloading alabaster-1.0.0-py3-none-any.whl (13 kB)
# Downloading babel-2.16.0-py3-none-any.whl (9.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
# Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
# Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
# Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
# Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Building wheels for collected packages: matplotlib-venn, bibtexparser, sgmllib3k
#   Building wheel for matplotlib-venn (pyproject.toml) ... done
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.1-py3-none-any.whl size=45289 sha256=9f0273f6131d37ddaa76467df6c1bd38eb60b42fe410ae11ac69cacf86c65e28
#   Stored in directory: /Users/kuntal/Library/Caches/pip/wheels/08/28/f0/0a3240d632a27df6da04d2888a6b058c37e1cbbb425ec5d2cc
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.2-py3-none-any.whl size=43562 sha256=a86b0dff8b619843876fa0c6fe10554f42301eb97987bb2da46a78abe44de827
#   Stored in directory: /Users/kuntal/Library/Caches/pip/wheels/da/e4/44/a7b72af06f3d2b28f4b56ad88b274743ed10ec52f503f22e80
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6047 sha256=a95af9c7c7b96ca0d125abc63ee1f058016018c979ea91e8632efcc3ba529b49
#   Stored in directory: /Users/kuntal/Library/Caches/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built matplotlib-venn bibtexparser sgmllib3k
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^
# Installing collected packages: snowballstemmer, sgmllib3k, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, rapidfuzz, pygments, prettytable, pluggy, iniconfig, imagesize, humanfriendly, feedparser, et-xmlfile, bibtexparser, babel, alabaster, thefuzz, sphinx, pytest, pymed-paperscraper, openpyxl, coloredlogs, arxiv, sphinxcontrib-jquery, simple-loggers, matplotlib-venn, webrequests, sql-manager, sphinx-rtd-theme, scholarly, impact-factor, paperscraper
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.14.0
#     Uninstalling Pygments-2.14.0:
#       Successfully uninstalled Pygments-2.14.0
#   WARNING: The script pygmentize is installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script humanfriendly is installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybabel is installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts sphinx-apidoc, sphinx-autogen, sphinx-build and sphinx-quickstart are installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts py.test and pytest are installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script coloredlogs is installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts IF and impact_factor are installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed alabaster-1.0.0 arxiv-2.1.3 babel-2.16.0 bibtexparser-1.4.2 coloredlogs-15.0.1 et-xmlfile-2.0.0 feedparser-6.0.11 humanfriendly-10.0 imagesize-1.4.1 impact-factor-1.1.2 iniconfig-2.0.0 matplotlib-venn-1.1.1 openpyxl-3.1.5 paperscraper-0.2.14 pluggy-1.5.0 prettytable-3.12.0 pygments-2.14.0 pymed-paperscraper-0.0.1 pytest-8.3.3 rapidfuzz-3.10.1 scholarly-1.7.11 sgmllib3k-1.0.0 simple-loggers-1.0.5 snowballstemmer-2.2.0 sphinx-8.1.3 sphinx-rtd-theme-3.0.2 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0 sql-manager-1.0.5 thefuzz-0.22.1 webrequests-1.0.8
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # COMPUTER SCIENCE

# %%
import os
from paperscraper.arxiv import get_and_dump_arxiv_papers
from paperscraper.pdf import save_pdf_from_dump

# Define the years and base path
years = ['2024', '2023', '2022', '2021', '2020']
base_path = "/Users/kuntal/Documents/Github/arxiv scraper"
pdf_directory = os.path.join(base_path, 'pdfs')

# Create a directory named 'pdfs' if it doesn't exist
os.makedirs(pdf_directory, exist_ok=True)

for year in years:
    # Define the query for the specific year
    query = [['cs'], [year]]

    # Set the metadata file for each year
    metadata_filepath = os.path.join(base_path, f'arxiv_cs_{year}.jsonl')

    # Fetch and dump arXiv papers metadata
    get_and_dump_arxiv_papers(query, output_filepath=metadata_filepath)

    # Download and save PDFs to the 'pdfs' directory
    save_pdf_from_dump(metadata_filepath, pdf_path=pdf_directory, key_to_save='doi')

    print(f"Papers for {year} have been saved to the '{pdf_directory}' directory.")
# Out:
# Processing (all:cs) AND (all:2024): 694it [00:30, 22.72it/s]
# Processing paper 1/694:   0%|          | 0/694 [00:00<?, ?it/s]/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/paperscraper/pdf.py:46: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.text, features="lxml")
# Processing paper 694/694: 100%|██████████| 694/694 [27:55<00:00,  2.41s/it]
# Papers for 2024 have been saved to the '/Users/kuntal/Documents/Github/arxiv scraper/pdfs' directory.
# Processing (all:cs) AND (all:2023): 692it [00:30, 22.94it/s]
# Processing paper 1/692:   0%|          | 0/692 [00:00<?, ?it/s]/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/paperscraper/pdf.py:46: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.text, features="lxml")
# Processing paper 45/692:   6%|▋         | 44/692 [01:41<24:53,  2.30s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 24
#      21 get_and_dump_arxiv_papers(query, output_filepath=metadata_filepath)
#      23 # Download and save PDFs to the 'pdfs' directory
# ---> 24 save_pdf_from_dump(metadata_filepath, pdf_path=pdf_directory, key_to_save='doi')
#      26 print(f"Papers for {year} have been saved to the '{pdf_directory}' directory.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/paperscraper/pdf.py:101, in save_pdf_from_dump(dump_path, pdf_path, key_to_save)
#      99     continue
#     100 filename = paper[key_to_save].replace("/", "_")
# --> 101 save_pdf(paper, os.path.join(pdf_path, f"{filename}.pdf"))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/paperscraper/pdf.py:41, in save_pdf(paper_metadata, filepath)
#      39 url = f"https://doi.org/{paper_metadata['doi']}"
#      40 try:
# ---> 41     response = requests.get(url, timeout=60)
#      42 except Exception:
#      43     logger.warning(f"Could not download {url}.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
pip install arxiv

# %%
import arxiv
import time

# Define search parameters
search_query = "cat:cs"  # Topic of interest
start_date = "2024-01-01"
end_date = "2024-11-20"


# Initialize pagination parameters
max_results_per_call = 100  # Maximum results per API call
start_index = 0             # Starting index for pagination
all_results = []            # List to store all retrieved results


while True:
    # Perform search with pagination
    search = arxiv.Search(
        query=search_query,
        max_results=max_results_per_call,
        sort_by=arxiv.SortCriterion.SubmittedDate,
        sort_order=arxiv.SortOrder.Ascending,
        start=start_index,
        date_from=start_date,
        date_to=end_date
    )

    # Retrieve results
    results = list(search.results())

    if not results:
        # No more results to fetch
        break

    # Append retrieved results to the list
    all_results.extend(results)

    # Update start_index for next batch
    start_index += max_results_per_call

    # Respect arXiv's rate limits by adding a delay between requests
    time.sleep(3)  # 3-second delay

print(f"Total papers retrieved: {len(all_results)}")

# %% [markdown]
# # api

# %%
import os
import requests
import time
from datetime import datetime
import feedparser

# Define search parameters
search_query = "cat:cs.*"  # Computer Science category
year = 2024
max_results_per_call = 100  # Maximum results per API call
total_papers_to_download = 3000  # Total number of papers to download
base_url = "http://export.arxiv.org/api/query?"

# Directory structure
base_dir = "pdfs"
year_dir = os.path.join(base_dir, str(year))
os.makedirs(year_dir, exist_ok=True)

# Function to fetch papers from arXiv API
def fetch_papers(start_index, max_results):
    query = f"search_query={search_query}&start={start_index}&max_results={max_results}&sortBy=submittedDate&sortOrder=descending"
    response = requests.get(base_url + query)
    response.raise_for_status()
    return feedparser.parse(response.text)

# Function to download PDF
def download_pdf(pdf_url, pdf_filename):
    try:
        print(f"Downloading {pdf_url}...")
        response = requests.get(pdf_url)
        response.raise_for_status()
        with open(pdf_filename, "wb") as pdf_file:
            pdf_file.write(response.content)
        print(f"Saved to {pdf_filename}")
    except Exception as e:
        print(f"Failed to download {pdf_url}: {e}")

# Main loop to fetch and download papers
downloaded_count = 0
start_index = 0

while downloaded_count < total_papers_to_download:
    try:
        feed = fetch_papers(start_index, max_results_per_call)
        entries = feed.entries

        if not entries:
            print("No more entries found or received an empty page.")
            break

        for entry in entries:
            published_year = datetime.strptime(entry.published, "%Y-%m-%dT%H:%M:%SZ").year
            if published_year == year:
                pdf_url = entry.link.replace("abs", "pdf") + ".pdf"
                pdf_filename = os.path.join(year_dir, f"{entry.id.split('/')[-1]}.pdf")
                if not os.path.exists(pdf_filename):
                    download_pdf(pdf_url, pdf_filename)
                    downloaded_count += 1
                    if downloaded_count >= total_papers_to_download:
                        break

        start_index += max_results_per_call
        time.sleep(3)  # Pause to respect arXiv's rate limits

    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}. Retrying after a pause.")
        time.sleep(10)  # Wait before retrying

print(f"Downloaded {downloaded_count} papers to {year_dir}")
# Out:
# Downloading http://arxiv.org/pdf/2411.13553v1.pdf...
# Saved to pdfs/2024/2411.13553v1.pdf
# No more entries found or received an empty page.
# Downloaded 1 papers to pdfs/2024

# %%
#  arXiv's OAI-PMH

# %%
import os
import requests
import time
from datetime import datetime
import feedparser

# Define search parameters
search_query = "cat:cs.*"  # Computer Science category
year = 2024
max_results_per_call = 100  # Maximum results per API call
total_papers_to_download = 3000  # Total number of papers to download
base_url = "http://export.arxiv.org/api/query?"

# Directory structure
base_dir = "pdfs"
year_dir = os.path.join(base_dir, str(year))
os.makedirs(year_dir, exist_ok=True)

# Function to fetch papers from arXiv API
def fetch_papers(start_index, max_results):
    query = f"search_query={search_query}&start={start_index}&max_results={max_results}&sortBy=submittedDate&sortOrder=descending"
    response = requests.get(base_url + query)
    response.raise_for_status()
    return feedparser.parse(response.text)

# Function to download PDF
def download_pdf(pdf_url, pdf_filename):
    try:
        print(f"Downloading {pdf_url}...")
        response = requests.get(pdf_url)
        response.raise_for_status()
        with open(pdf_filename, "wb") as pdf_file:
            pdf_file.write(response.content)
        print(f"Saved to {pdf_filename}")
    except Exception as e:
        print(f"Failed to download {pdf_url}: {e}")

# Main loop to fetch and download papers
downloaded_count = 0
start_index = 0

while downloaded_count < total_papers_to_download:
    try:
        feed = fetch_papers(start_index, max_results_per_call)
        entries = feed.entries

        if not entries:
            print("No more entries found or received an empty page.")
            break

        for entry in entries:
            published_year = datetime.strptime(entry.published, "%Y-%m-%dT%H:%M:%SZ").year
            if published_year == year:
                pdf_url = entry.link.replace("abs", "pdf") + ".pdf"
                pdf_filename = os.path.join(year_dir, f"{entry.id.split('/')[-1]}.pdf")
                if not os.path.exists(pdf_filename):
                    download_pdf(pdf_url, pdf_filename)
                    downloaded_count += 1
                    if downloaded_count >= total_papers_to_download:
                        break

        start_index += max_results_per_call
        time.sleep(3)  # Pause to respect arXiv's rate limits

    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}. Retrying after a pause.")
        time.sleep(10)  # Wait before retrying

print(f"Downloaded {downloaded_count} papers to {year_dir}")
# Out:
# Downloading http://arxiv.org/pdf/2411.13552v1.pdf...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 57
#      55 pdf_filename = os.path.join(year_dir, f"{entry.id.split('/')[-1]}.pdf")
#      56 if not os.path.exists(pdf_filename):
# ---> 57     download_pdf(pdf_url, pdf_filename)
#      58     downloaded_count += 1
#      59     if downloaded_count >= total_papers_to_download:
#
# Cell In[18], line 30, in download_pdf(pdf_url, pdf_filename)
#      28 try:
#      29     print(f"Downloading {pdf_url}...")
# ---> 30     response = requests.get(pdf_url)
#      31     response.raise_for_status()
#      32     with open(pdf_filename, "wb") as pdf_file:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
#  # arXiv's OAI-PMH

# %%
pip install sickle requests
# Out:
# Collecting sickle
#   Downloading Sickle-0.7.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: lxml>=3.2.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sickle) (4.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests) (2024.8.30)
# Downloading Sickle-0.7.0-py3-none-any.whl (12 kB)
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^
# Installing collected packages: sickle
# Successfully installed sickle-0.7.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sickle import Sickle
from sickle.models import Record
import time
import requests
import os

# Initialize the Sickle client with the arXiv OAI-PMH endpoint
sickle = Sickle('http://export.arxiv.org/oai2')

# Define the parameters for the ListRecords request
params = {
    'metadataPrefix': 'arXiv',
    'set': 'cs',          # Computer Science category
    'from': '2024-01-01',
    'until': '2024-12-31'
}

# Define the base directory where PDFs will be saved
base_dir = '/Users/kuntal/Documents/Github/arxiv scraper/pdfs'

# Create the year directory inside the base directory
year = '2024'
year_dir = os.path.join(base_dir, year)
os.makedirs(year_dir, exist_ok=True)

# Retrieve records from the OAI-PMH interface
records = sickle.ListRecords(**params)

# Counter for tracking the number of papers downloaded
paper_count = 0

# Iterate over the records and download PDFs
for record in records:
    if isinstance(record, Record):
        metadata = record.metadata
        arxiv_id = metadata.get('id')[0]

        # Download the PDF
        pdf_url = f"http://arxiv.org/pdf/{arxiv_id}.pdf"
        try:
            response = requests.get(pdf_url, timeout=10)
            response.raise_for_status()
            # Replace slashes in arXiv ID to avoid directory issues
            pdf_filename = f"{arxiv_id.replace('/', '_')}.pdf"
            pdf_path = os.path.join(year_dir, pdf_filename)
            with open(pdf_path, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded PDF: {pdf_path}")
            paper_count += 1
        except requests.exceptions.RequestException as e:
            print(f"Failed to download PDF for {arxiv_id}: {e}")

        # Be polite and avoid overwhelming the server
        time.sleep(3)
    else:
        print("No more records.")
        break

print(f"Total papers downloaded: {paper_count}")
# Out:
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0705.1329.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0710.3901.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0802.3284.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0802.3300.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0802.3414.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0803.0966.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0806.1636.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0808.0163.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0808.0521.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0811.1449.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0901.0044.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0901.1988.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0903.2016.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0903.4826.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0904.3742.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0905.3108.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0911.0105.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/0911.5246.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1004.3702.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1005.1871.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1005.2465.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1005.4648.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1006.2883.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1008.2715.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1011.2973.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1101.0350.pdf
# Failed to download PDF for 1102.1087: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1102.1087
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1102.2604.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1103.0494.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1104.2444.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1104.3314.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1106.5213.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1107.0237.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1107.3279.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1108.1791.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1108.5475.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1109.2669.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1109.6273.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1109.6622.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1110.2317.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1110.2615.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1110.4034.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1110.4307.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1110.4507.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1111.4181.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1111.5595.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1111.6473.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1111.6807.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1112.1768.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1202.0085.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1202.0322.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1202.1238.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1202.4664.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1203.0550.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1203.4040.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1204.1134.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1204.3569.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1205.5856.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1205.5921.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1206.1892.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1206.3965.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1207.0258.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1207.3365.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1209.0308.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1209.2079.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1209.4970.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1210.8326.pdf
# Failed to download PDF for 1211.5656: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1211.5656
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1211.6188.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1212.0494.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1212.5289.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1301.3870.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1301.4016.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1301.6714.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1303.1778.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1303.2033.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1303.2967.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1303.4315.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1304.5774.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1304.7435.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1305.5617.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1306.1138.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1308.0497.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1308.2910.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1309.0193.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1309.7583.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1310.4149.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1311.2191.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1311.3269.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1311.4566.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1312.2169.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1312.3092.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1312.5572.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1401.2411.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1401.3801.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1402.5593.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1403.1076.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1403.2001.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1403.3369.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1403.4060.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1403.4434.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1403.6207.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1404.0736.pdf
# Failed to download PDF for 1404.4599: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1404.4599
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1404.6055.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1404.7442.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1405.0086.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1405.1300.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1405.1523.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1405.4806.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1405.6503.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1406.0134.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1406.0650.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1406.1777.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1406.6046.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1407.4992.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1407.7504.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1408.2214.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1408.3297.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1409.1786.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1409.7291.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1410.0277.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1410.3998.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1410.5420.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1410.6455.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1410.6652.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1410.7868.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1411.0401.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1411.2547.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1411.2548.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1411.2549.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1411.2668.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1411.3603.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1411.7315.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1501.00950.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1501.01332.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1501.01678.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1502.02218.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1502.04226.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1503.00879.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1503.01398.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1503.01438.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1503.02173.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1503.05477.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1503.08992.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1504.03498.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1504.05764.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1504.06817.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1505.00412.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1505.02681.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1505.05663.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1506.02247.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1506.02890.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1506.02937.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1506.03410.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1507.00953.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1507.01546.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1507.02750.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1507.07727.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1507.07755.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1508.01167.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1508.07885.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1509.01116.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1509.08392.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1510.01008.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1510.01363.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1510.03045.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1511.03086.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1511.04143.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1511.05240.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1512.02317.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1512.02512.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1512.03139.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1512.04637.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1512.09207.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1601.03164.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1601.05927.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1601.07810.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1602.04581.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1602.05829.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1603.00751.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1603.01983.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1603.02004.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1603.02642.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1603.06757.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1603.07462.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1603.08735.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1604.00357.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1604.00635.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1604.04792.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1604.05897.pdf
# Failed to download PDF for 1605.00167: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1605.00167
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1605.01212.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1605.05808.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1605.07896.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.00963.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.01689.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.03137.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.05127.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.07757.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.07886.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.08357.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.08970.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1606.09176.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1607.00223.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1607.01327.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1607.01818.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1607.02291.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1607.02502.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1607.04559.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1607.06444.pdf
# Failed to download PDF for 1608.02530: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1608.02530
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1608.03417.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1608.05787.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1608.07876.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.00004.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.00317.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.01190.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.02209.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.05672.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.05693.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.05867.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.07528.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.07630.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1609.08089.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1610.00291.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1610.00353.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1610.02496.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1610.07252.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1610.07914.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1610.09320.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.03267.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.03398.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.05590.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.06097.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.06189.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.06430.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.06544.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1611.08057.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1612.03551.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1612.04338.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1612.04861.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1612.06092.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1612.06749.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1612.07844.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1612.08709.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.00302.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.02415.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.03234.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.03290.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.05944.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.06104.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.06991.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.07275.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1701.08338.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1702.00249.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1702.03096.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1702.03726.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1702.05614.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1702.07213.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1702.07324.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.00242.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.01347.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.03166.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.04901.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.05503.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.05537.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.05834.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.06261.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.06611.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.07876.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.08046.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1703.08853.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1704.01142.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1704.01918.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1704.04244.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1704.04370.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.01809.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.03736.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.06011.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.06040.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.07305.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.07533.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.08439.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.09369.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.09756.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1705.10915.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1706.00178.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1706.00782.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1706.00933.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1706.02149.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1706.04595.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1706.06944.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1706.08941.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.00519.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.02612.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.04071.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.04514.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.05558.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.07545.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.08089.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.08446.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.08849.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.08898.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1707.09933.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.00087.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.00523.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.00905.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.05264.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.07788.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.08320.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.08723.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.09151.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.09157.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1708.09684.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.00668.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.01062.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.02618.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.03690.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.04044.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.04402.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.05958.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.06995.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.07121.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.07480.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.08840.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.10048.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1709.10453.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.00095.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.00983.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.01837.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.04238.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.04872.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.05267.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.07634.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.10345.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.10830.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1710.10888.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.00155.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.00603.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.00726.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.01183.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.01479.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.01820.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.02843.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.04366.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.05220.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.05650.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.06041.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.07116.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.09157.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.09428.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1711.10694.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.00158.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.00690.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.00960.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.05876.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.06842.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.07503.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.07511.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.08493.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1712.09035.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1801.01587.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1801.03734.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1801.04064.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1801.07988.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1801.08270.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1801.10491.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.00906.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.02336.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.02820.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.03028.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.03308.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.03494.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.03498.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.05319.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.05843.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.05995.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.07687.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.09503.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.09697.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1802.09957.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.00679.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.02233.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.03724.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.04190.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.04660.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.06448.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.06488.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.06496.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.06887.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.07890.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.10547.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.10683.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1803.11521.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.00804.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.00805.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.00806.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.01814.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.01855.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.02075.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.02627.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.02917.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.02973.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.04317.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.04659.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.04868.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.05105.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.06291.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.06601.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.07000.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.07055.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.08155.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.08445.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.08982.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.09223.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.10729.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.11142.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1804.11222.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.04419.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.04487.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.04770.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.06299.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.06775.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.07018.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.07776.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.08380.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.08606.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.08708.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.08925.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.10330.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.11722.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1805.12042.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.02770.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.02935.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.05451.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.05514.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.08392.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.08664.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.08936.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.09236.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.09385.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.10866.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1806.11236.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.01287.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.01369.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.02227.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.02323.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.03142.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.03162.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.04000.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.04406.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.05385.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.05443.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.05477.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.05812.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.05993.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.06190.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.06725.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.08011.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.08302.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.09932.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.10027.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.10441.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.10562.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.11110.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1807.11456.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.00601.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.01356.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.02357.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.02451.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.02860.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.02933.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.02950.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.03327.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.03881.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.04464.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.04465.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.04750.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.05145.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.05671.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.06256.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.07380.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.07840.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.08217.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.09334.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.10024.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1808.10203.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.00928.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.01002.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.01653.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.01701.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.01717.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.03014.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.03158.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.04564.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.05955.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.06699.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.06751.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.08835.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.09849.pdf
# Failed to download PDF for 1809.09861: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1809.09861
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1809.10469.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.00140.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.00197.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.01111.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.01864.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.02897.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.03369.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.03393.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.03955.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.03980.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.04006.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.04788.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.05420.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.05691.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.06612.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.06806.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.07746.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.08086.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.08749.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.08774.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.11826.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.12813.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.13029.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.13306.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1810.13431.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.01331.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.01661.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.02641.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.02733.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.03019.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.04035.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.04494.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.04757.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.05422.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.05727.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.06026.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.06139.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.06609.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.06787.pdf
# Failed to download PDF for 1811.08075: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1811.08075
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.08942.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.09537.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.09539.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.11097.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.11806.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1811.12852.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.00029.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.00117.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.00352.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.00924.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.01164.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.01170.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.01243.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.01339.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/1812.01973.pdf
# ...
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.01436.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.01714.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02019.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02206.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02222.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02410.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02438.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02493.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02556.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02596.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02726.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02857.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02876.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02912.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.02933.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03158.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03361.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03372.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03425.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03527.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03652.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03664.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03673.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.03893.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04026.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04181.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04208.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04310.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04492.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04566.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04570.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04572.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04623.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04785.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.04987.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.05031.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.05326.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.05463.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.05467.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.05512.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.05536.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.05943.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.06136.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.06411.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.06685.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.06714.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.06795.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.06824.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.06908.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07264.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07278.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07324.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07515.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07551.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07563.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.07746.pdf
# Failed to download PDF for 2104.08029: HTTPConnectionPool(host='arxiv.org', port=80): Read timed out.
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.08184.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.08390.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.08433.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.08540.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.08594.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.08634.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.08870.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.08928.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09008.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09029.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09080.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09137.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09290.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09350.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09445.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09627.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09641.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09823.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.09858.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.10446.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.10489.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.10561.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.10746.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.10751.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.10812.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.11105.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.11123.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.11184.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.11241.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.11448.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.11808.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.11946.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12156.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12294.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12313.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12333.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12445.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12508.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12581.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12582.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12668.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12678.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.12964.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13026.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13040.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13046.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13130.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13353.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13395.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13663.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13690.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13713.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13753.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13785.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13844.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.13894.pdf
# Downloaded PDF: /Users/kuntal/Documents/Github/arxiv scraper/pdfs/2024/2104.14172.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 41
#      39 pdf_url = f"http://arxiv.org/pdf/{arxiv_id}.pdf"
#      40 try:
# ---> 41     response = requests.get(pdf_url, timeout=10)
#      42     response.raise_for_status()
#      43     # Replace slashes in arXiv ID to avoid directory issues
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # only 2 column format papers

# %%
from sickle import Sickle
from sickle.models import Record
import time
import requests
import os
from PyPDF2 import PdfReader

# Initialize the Sickle client with the arXiv OAI-PMH endpoint
sickle = Sickle('http://export.arxiv.org/oai2')

# Define the parameters for the ListRecords request
params = {
    'metadataPrefix': 'arXiv',
    'set': 'cs',          # Computer Science category
    'from': '2024-01-01',
    'until': '2024-12-31'
}

# Define the base directory where PDFs will be saved
base_dir = '/Users/kuntal/Documents/Github/arxiv_scraper/pdfs-2columns-format'

# Create the year directory inside the base directory
year = '2024'
year_dir = os.path.join(base_dir, year)
os.makedirs(year_dir, exist_ok=True)

# Function to check if a PDF is two-column formatted
def is_two_column(pdf_path):
    try:
        reader = PdfReader(pdf_path)
        first_page = reader.pages[0]  # Only check the first page
        # Analyze text positions or layout to detect two-column structure
        # Placeholder: Actual implementation depends on library capabilities
        text_positions = first_page.extract_text()  # Example; refine as needed
        # Logic to analyze column layout
        return "two-column criteria" in text_positions  # Replace with actual logic
    except Exception as e:
        print(f"Error reading PDF {pdf_path}: {e}")
        return False

# Retrieve records from the OAI-PMH interface
records = sickle.ListRecords(**params)

# Counter for tracking the number of papers downloaded
paper_count = 0

# Iterate over the records and download PDFs
for record in records:
    if isinstance(record, Record):
        metadata = record.metadata
        arxiv_id = metadata.get('id')[0]

        # Download the PDF temporarily for checking
        pdf_url = f"http://arxiv.org/pdf/{arxiv_id}.pdf"
        temp_pdf_path = os.path.join(year_dir, f"temp_{arxiv_id.replace('/', '_')}.pdf")
        try:
            response = requests.get(pdf_url, timeout=10)
            response.raise_for_status()
            with open(temp_pdf_path, 'wb') as f:
                f.write(response.content)

            # Check if the PDF is two-column formatted
            if is_two_column(temp_pdf_path):
                pdf_filename = f"{arxiv_id.replace('/', '_')}.pdf"
                final_pdf_path = os.path.join(year_dir, pdf_filename)
                os.rename(temp_pdf_path, final_pdf_path)
                print(f"Downloaded two-column PDF: {final_pdf_path}")
                paper_count += 1
            else:
                os.remove(temp_pdf_path)  # Delete the non-matching PDF
                print(f"Skipped non-two-column PDF: {arxiv_id}")

        except requests.exceptions.RequestException as e:
            print(f"Failed to download PDF for {arxiv_id}: {e}")
            if os.path.exists(temp_pdf_path):
                os.remove(temp_pdf_path)

        # Be polite and avoid overwhelming the server
        time.sleep(3)
    else:
        print("No more records.")
        break

print(f"Total two-column papers downloaded: {paper_count}")
# Out:
# Skipped non-two-column PDF: 0705.1329
# Skipped non-two-column PDF: 0710.3901
# Skipped non-two-column PDF: 0802.3284
# Skipped non-two-column PDF: 0802.3300
# Skipped non-two-column PDF: 0802.3414
# Skipped non-two-column PDF: 0803.0966
# Skipped non-two-column PDF: 0806.1636
# Skipped non-two-column PDF: 0808.0163
# Skipped non-two-column PDF: 0808.0521
# Skipped non-two-column PDF: 0811.1449
# Skipped non-two-column PDF: 0901.0044
# Skipped non-two-column PDF: 0901.1988
# Skipped non-two-column PDF: 0903.2016
# Skipped non-two-column PDF: 0903.4826
# Skipped non-two-column PDF: 0904.3742
# Skipped non-two-column PDF: 0905.3108
# Skipped non-two-column PDF: 0911.0105
# Skipped non-two-column PDF: 0911.5246
# Skipped non-two-column PDF: 1004.3702
# Skipped non-two-column PDF: 1005.1871
# Skipped non-two-column PDF: 1005.2465
# Skipped non-two-column PDF: 1005.4648
# Skipped non-two-column PDF: 1006.2883
# Skipped non-two-column PDF: 1008.2715
# Skipped non-two-column PDF: 1011.2973
# Skipped non-two-column PDF: 1101.0350
# Failed to download PDF for 1102.1087: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1102.1087
# Skipped non-two-column PDF: 1102.2604
# Skipped non-two-column PDF: 1103.0494
# Skipped non-two-column PDF: 1104.2444
# Skipped non-two-column PDF: 1104.3314
# Skipped non-two-column PDF: 1106.5213
# Skipped non-two-column PDF: 1107.0237
# Skipped non-two-column PDF: 1107.3279
# Skipped non-two-column PDF: 1108.1791
# Skipped non-two-column PDF: 1108.5475
# Skipped non-two-column PDF: 1109.2669
# Skipped non-two-column PDF: 1109.6273
# Skipped non-two-column PDF: 1109.6622
# Skipped non-two-column PDF: 1110.2317
# Skipped non-two-column PDF: 1110.2615
# Skipped non-two-column PDF: 1110.4034
# Skipped non-two-column PDF: 1110.4307
# Skipped non-two-column PDF: 1110.4507
# Skipped non-two-column PDF: 1111.4181
# Skipped non-two-column PDF: 1111.5595
# Skipped non-two-column PDF: 1111.6473
# Skipped non-two-column PDF: 1111.6807
# Skipped non-two-column PDF: 1112.1768
# Skipped non-two-column PDF: 1202.0085
# Skipped non-two-column PDF: 1202.0322
# Skipped non-two-column PDF: 1202.1238
# Skipped non-two-column PDF: 1202.4664
# Skipped non-two-column PDF: 1203.0550
# Skipped non-two-column PDF: 1203.4040
# Skipped non-two-column PDF: 1204.1134
# Skipped non-two-column PDF: 1204.3569
# Skipped non-two-column PDF: 1205.5856
# Skipped non-two-column PDF: 1205.5921
# Skipped non-two-column PDF: 1206.1892
# Skipped non-two-column PDF: 1206.3965
# Skipped non-two-column PDF: 1207.0258
# Skipped non-two-column PDF: 1207.3365
# Skipped non-two-column PDF: 1209.0308
# Skipped non-two-column PDF: 1209.2079
# Skipped non-two-column PDF: 1209.4970
# Skipped non-two-column PDF: 1210.8326
# Failed to download PDF for 1211.5656: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1211.5656
# Skipped non-two-column PDF: 1211.6188
# Skipped non-two-column PDF: 1212.0494
# Skipped non-two-column PDF: 1212.5289
# unknown widths :
# [0, IndirectObject(114, 0, 4911694160)]
# unknown widths :
# [0, IndirectObject(132, 0, 4911694160)]
# unknown widths :
# [0, IndirectObject(127, 0, 4911694160)]
# unknown widths :
# [0, IndirectObject(138, 0, 4911694160)]
# unknown widths :
# [0, IndirectObject(118, 0, 4911694160)]
# unknown widths :
# [0, IndirectObject(137, 0, 4911694160)]
# unknown widths :
# [0, IndirectObject(122, 0, 4911694160)]
# unknown widths :
# [0, IndirectObject(142, 0, 4911694160)]
# Skipped non-two-column PDF: 1301.3870
# Skipped non-two-column PDF: 1301.4016
# unknown widths :
# [0, IndirectObject(151, 0, 4912374288)]
# unknown widths :
# [0, IndirectObject(167, 0, 4912374288)]
# unknown widths :
# [0, IndirectObject(161, 0, 4912374288)]
# unknown widths :
# [0, IndirectObject(146, 0, 4912374288)]
# unknown widths :
# [0, IndirectObject(139, 0, 4912374288)]
# unknown widths :
# [0, IndirectObject(156, 0, 4912374288)]
# unknown widths :
# [0, IndirectObject(171, 0, 4912374288)]
# unknown widths :
# [0, IndirectObject(166, 0, 4912374288)]
# unknown widths :
# [0, IndirectObject(147, 0, 4912374288)]
# Skipped non-two-column PDF: 1301.6714
# Skipped non-two-column PDF: 1303.1778
# Skipped non-two-column PDF: 1303.2033
# Skipped non-two-column PDF: 1303.2967
# Skipped non-two-column PDF: 1303.4315
# Skipped non-two-column PDF: 1304.5774
# Skipped non-two-column PDF: 1304.7435
# Skipped non-two-column PDF: 1305.5617
# Skipped non-two-column PDF: 1306.1138
# Skipped non-two-column PDF: 1308.0497
# Skipped non-two-column PDF: 1308.2910
# Skipped non-two-column PDF: 1309.0193
# Skipped non-two-column PDF: 1309.7583
# Skipped non-two-column PDF: 1310.4149
# Skipped non-two-column PDF: 1311.2191
# Skipped non-two-column PDF: 1311.3269
# Skipped non-two-column PDF: 1311.4566
# Skipped non-two-column PDF: 1312.2169
# Skipped non-two-column PDF: 1312.3092
# Skipped non-two-column PDF: 1312.5572
# Skipped non-two-column PDF: 1401.2411
# Skipped non-two-column PDF: 1401.3801
# Skipped non-two-column PDF: 1402.5593
# Skipped non-two-column PDF: 1403.1076
# Skipped non-two-column PDF: 1403.2001
# Skipped non-two-column PDF: 1403.3369
# Skipped non-two-column PDF: 1403.4060
# Skipped non-two-column PDF: 1403.4434
# Skipped non-two-column PDF: 1403.6207
# Skipped non-two-column PDF: 1404.0736
# Failed to download PDF for 1404.4599: 404 Client Error: Not Found for url: http://arxiv.org/pdf/1404.4599
# Skipped non-two-column PDF: 1404.6055
# Skipped non-two-column PDF: 1404.7442
# Skipped non-two-column PDF: 1405.0086
# Skipped non-two-column PDF: 1405.1300
# Skipped non-two-column PDF: 1405.1523
# Skipped non-two-column PDF: 1405.4806
# Skipped non-two-column PDF: 1405.6503
# Skipped non-two-column PDF: 1406.0134
# Skipped non-two-column PDF: 1406.0650
# Skipped non-two-column PDF: 1406.1777
# Skipped non-two-column PDF: 1406.6046
# Skipped non-two-column PDF: 1407.4992
# Skipped non-two-column PDF: 1407.7504
# Skipped non-two-column PDF: 1408.2214
# Skipped non-two-column PDF: 1408.3297
# Skipped non-two-column PDF: 1409.1786
# Skipped non-two-column PDF: 1409.7291
# Skipped non-two-column PDF: 1410.0277
# Skipped non-two-column PDF: 1410.3998
# Skipped non-two-column PDF: 1410.5420
# Skipped non-two-column PDF: 1410.6455
# Skipped non-two-column PDF: 1410.6652
# Skipped non-two-column PDF: 1410.7868
# Skipped non-two-column PDF: 1411.0401
# Skipped non-two-column PDF: 1411.2547
# Skipped non-two-column PDF: 1411.2548
# Skipped non-two-column PDF: 1411.2549
# Skipped non-two-column PDF: 1411.2668
# Skipped non-two-column PDF: 1411.3603
# Skipped non-two-column PDF: 1411.7315
# Skipped non-two-column PDF: 1501.00950
# Skipped non-two-column PDF: 1501.01332
# Skipped non-two-column PDF: 1501.01678
# Skipped non-two-column PDF: 1502.02218
# Skipped non-two-column PDF: 1502.04226
# Skipped non-two-column PDF: 1503.00879
# Skipped non-two-column PDF: 1503.01398
# Skipped non-two-column PDF: 1503.01438
# Skipped non-two-column PDF: 1503.02173
# Skipped non-two-column PDF: 1503.05477
# Skipped non-two-column PDF: 1503.08992
# Skipped non-two-column PDF: 1504.03498
# Skipped non-two-column PDF: 1504.05764
# Skipped non-two-column PDF: 1504.06817
# Skipped non-two-column PDF: 1505.00412
# Skipped non-two-column PDF: 1505.02681
# Skipped non-two-column PDF: 1505.05663
# Skipped non-two-column PDF: 1506.02247
# Skipped non-two-column PDF: 1506.02890
# Skipped non-two-column PDF: 1506.02937
# Skipped non-two-column PDF: 1506.03410
# Skipped non-two-column PDF: 1507.00953
# Skipped non-two-column PDF: 1507.01546
# Skipped non-two-column PDF: 1507.02750
# Skipped non-two-column PDF: 1507.07727
# Skipped non-two-column PDF: 1507.07755
# Skipped non-two-column PDF: 1508.01167
# Skipped non-two-column PDF: 1508.07885
# Skipped non-two-column PDF: 1509.01116
# Skipped non-two-column PDF: 1509.08392
# Skipped non-two-column PDF: 1510.01008
# Skipped non-two-column PDF: 1510.01363
# Skipped non-two-column PDF: 1510.03045
# Skipped non-two-column PDF: 1511.03086
# Skipped non-two-column PDF: 1511.04143
# Skipped non-two-column PDF: 1511.05240
# Skipped non-two-column PDF: 1512.02317
# Skipped non-two-column PDF: 1512.02512
# Skipped non-two-column PDF: 1512.03139
# Skipped non-two-column PDF: 1512.04637
# Skipped non-two-column PDF: 1512.09207
# Skipped non-two-column PDF: 1601.03164
# Skipped non-two-column PDF: 1601.05927
# Skipped non-two-column PDF: 1601.07810
# Skipped non-two-column PDF: 1602.04581
# Skipped non-two-column PDF: 1602.05829
# Skipped non-two-column PDF: 1603.00751
# Skipped non-two-column PDF: 1603.01983
# Skipped non-two-column PDF: 1603.02004
# Skipped non-two-column PDF: 1603.02642
# Skipped non-two-column PDF: 1603.06757
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 57
#      55 temp_pdf_path = os.path.join(year_dir, f"temp_{arxiv_id.replace('/', '_')}.pdf")
#      56 try:
# ---> 57     response = requests.get(pdf_url, timeout=10)
#      58     response.raise_for_status()
#      59     with open(temp_pdf_path, 'wb') as f:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:724, in <listcomp>(.0)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
